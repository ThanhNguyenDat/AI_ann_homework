# %%
import os
import glob

import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
import keras

# %%
# load image
path_dir = os.path.join(os.getcwd(), 'image')
path_dir = sorted(glob.glob(path_dir + '/*'))

Duc = glob.glob(path_dir[0] + '/*.jpg')
Phuoc = glob.glob(path_dir[1] + '/*.jpg')
Thanh = glob.glob(path_dir[2] + '/*.jpg')

# %%
img_cnt = len(Duc) + len(Phuoc) + len(Thanh)
print(img_cnt)

class_names = ['Duc', 'Phuoc', 'Thanh']
num_classes = len(class_names)
print(class_names)
# Out:
# 125
# ['Duc', 'Phuoc', 'Thanh']

# %%
def load_image(path, img_size=(180, 180)):
    img = cv2.imread(path, 1)
    img = cv2.resize(img, img_size)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # OpenCV loads images with color channels
    # in BGR order. So we need to reverse them
    return img

# %%
def load_images(path_dir):
    images = []
    labels = []

    path_dir = sorted(glob.glob(path_dir + '/*'))
    print(path_dir)
    for paths in path_dir:
        paths = sorted(glob.glob(paths + '/*.jpg'))
        for path in paths:
            img = load_image(path)
            images.append(img)
            labels.append(class_names.index(os.path.basename(os.path.dirname(path))))
    return np.array(images), np.array(labels)

# %%
data_dir = os.path.join(os.getcwd(), 'image')
dataset = load_images(data_dir)
# Out:
# ['/content/image/Duc', '/content/image/Phuoc', '/content/image/Thanh']

# %%
for i in range(9):
  # print(class_names[dataset[1][i]])
  plt.subplot(3, 3, i+1)
  plt.title(class_names[dataset[1][i]])
  plt.imshow(dataset[0][i])

# %%
print(dataset[0].shape)
print(dataset[1].shape)
# Out:
# (125, 180, 180, 3)
# (125,)

# %%
# train test split
train_images, test_images, train_labels, test_labels = train_test_split(dataset[0], dataset[1], test_size=0.2, random_state=42)
print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (100, 180, 180, 3)
# (25, 180, 180, 3)
# (100,)
# (25,)

# %%
train_images = train_images.reshape(train_images.shape[0], -1)
test_images = test_images.reshape(test_images.shape[0], -1)

train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

train_labels = keras.utils.np_utils.to_categorical(train_labels, num_classes)
test_labels = keras.utils.np_utils.to_categorical(test_labels, num_classes)

print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (100, 97200)
# (25, 97200)
# (100, 3)
# (25, 3)

# %%
def plot_history(history_fine):
  f1 = history_fine.history['acc']
  val_f1 = history_fine.history['val_acc']

  loss = history_fine.history['loss']
  val_loss = history_fine.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(f1, label='Acc')
  plt.plot(val_f1, label='Validation Acc')
  plt.legend(loc='lower right')
  plt.title('Accuracy')

  plt.subplot(2, 1, 2)
  plt.plot(loss, label='Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Loss')
  plt.xlabel('epoch')
  plt.show()

# %%
from keras.callbacks import EarlyStopping
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(256, activation='relu', input_shape = (train_images.shape[1],)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(train_labels.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer =tf.keras.optimizers.Adam(), metrics=['acc'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

history = model.fit(train_images, train_labels, batch_size = 128, epochs = 50, validation_split = 0.2, callbacks=[early_stopping])
model.save('classification_3_person')
plot_history(history)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.3015 - acc: 0.2500 - val_loss: 58.5931 - val_acc: 0.5500
# Epoch 2/50
# 1/1 [==============================] - 0s 301ms/step - loss: 66.3475 - acc: 0.3750 - val_loss: 166.6446 - val_acc: 0.2000
# Epoch 3/50
# 1/1 [==============================] - 0s 283ms/step - loss: 131.1348 - acc: 0.3750 - val_loss: 74.5570 - val_acc: 0.2000
# Epoch 4/50
# 1/1 [==============================] - 0s 335ms/step - loss: 56.5494 - acc: 0.3750 - val_loss: 6.5532 - val_acc: 0.3000
# Epoch 5/50
# 1/1 [==============================] - 0s 309ms/step - loss: 9.9811 - acc: 0.3000 - val_loss: 21.5613 - val_acc: 0.5500
# Epoch 6/50
# 1/1 [==============================] - 0s 290ms/step - loss: 33.7273 - acc: 0.3750 - val_loss: 24.2353 - val_acc: 0.5500
# Epoch 7/50
# 1/1 [==============================] - 0s 293ms/step - loss: 37.5657 - acc: 0.3750 - val_loss: 8.3600 - val_acc: 0.8000
# Epoch 8/50
# 1/1 [==============================] - 0s 325ms/step - loss: 16.3586 - acc: 0.6250 - val_loss: 3.4294 - val_acc: 0.8000
# Epoch 9/50
# 1/1 [==============================] - 0s 338ms/step - loss: 7.4627 - acc: 0.6250 - val_loss: 2.8475 - val_acc: 0.7000
# Epoch 10/50
# 1/1 [==============================] - 0s 292ms/step - loss: 1.2026 - acc: 0.8250 - val_loss: 5.2109 - val_acc: 0.5000
# Epoch 11/50
# 1/1 [==============================] - 0s 289ms/step - loss: 1.9904 - acc: 0.7125 - val_loss: 4.3190 - val_acc: 0.5000
# Epoch 12/50
# 1/1 [==============================] - 0s 332ms/step - loss: 1.7276 - acc: 0.6250 - val_loss: 9.2982e-07 - val_acc: 1.0000
# Epoch 13/50
# 1/1 [==============================] - 0s 452ms/step - loss: 5.9605e-09 - acc: 1.0000 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 14/50
# 1/1 [==============================] - 0s 265ms/step - loss: 2.9802e-09 - acc: 1.0000 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 15/50
# 1/1 [==============================] - 0s 277ms/step - loss: 2.3607e-04 - acc: 1.0000 - val_loss: 1.3471e-06 - val_acc: 1.0000
# Epoch 16/50
# 1/1 [==============================] - 0s 273ms/step - loss: 0.2114 - acc: 0.9500 - val_loss: 2.2951e-04 - val_acc: 1.0000
# Epoch 17/50
# 1/1 [==============================] - 0s 267ms/step - loss: 0.6908 - acc: 0.9125 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 18/50
# 1/1 [==============================] - 0s 268ms/step - loss: 0.8813 - acc: 0.8875 - val_loss: 0.0916 - val_acc: 0.9500
# Epoch 19/50
# 1/1 [==============================] - 0s 281ms/step - loss: 0.7898 - acc: 0.8750 - val_loss: 0.1022 - val_acc: 0.9500
# Epoch 20/50
# 1/1 [==============================] - 0s 259ms/step - loss: 0.5890 - acc: 0.9125 - val_loss: 1.4428e-05 - val_acc: 1.0000
# Epoch 21/50
# 1/1 [==============================] - 0s 269ms/step - loss: 0.2751 - acc: 0.9750 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 22/50
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0778 - acc: 0.9875 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 23/50
# 1/1 [==============================] - ETA: 0s - loss: 2.5248e-04 - acc: 1.0000Restoring model weights from the end of the best epoch: 13.
# 1/1 [==============================] - 0s 277ms/step - loss: 2.5248e-04 - acc: 1.0000 - val_loss: 0.0000e+00 - val_acc: 1.0000
# Epoch 23: early stopping
# INFO:tensorflow:Assets written to: classification_3_person/assets

# %%
print("test loss, test acc:", model.evaluate(test_images, test_labels))
# Out:
# 1/1 [==============================] - 0s 50ms/step - loss: 4.4534e-06 - acc: 1.0000
# test loss, test acc: [4.4534112930705305e-06, 1.0]

# %%
# from tensorflow.keras.preprocessing.image import load_img
# img_test = load_image('image/Duc/Duc_212.jpg')
# img_test = load_image('/content/image/Phuoc/Phuoc_244.jpg')
img_test = load_image('/content/image/Thanh/Thanh_112.jpg')

plt.imshow(img_test)
img_test = np.asarray(img_test)
img_test = img_test.reshape(-1)
img_test = img_test / 255
img_test = np.expand_dims(img_test, axis=0)

classe_num = np.argmax(model.predict(img_test))
plt.title("Predict: {}".format(class_names[classe_num]))
# Out:
# Text(0.5, 1.0, 'Predict: Thanh')
