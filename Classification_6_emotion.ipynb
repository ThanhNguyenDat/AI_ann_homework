# %%
import os
import glob

import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
import keras

# %% [markdown]
# # Link Dataset in Drive: https://drive.google.com/file/d/1EhOsf_BT9ht9uQhA3atjXTcf6VeQZexl/view?usp=sharing

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.chdir('/content/gdrive/MyDrive/Colab Notebooks/AI')
# !unzip dataset_6_class.zip
# !mkdir image
# !mv angry image
# !mv happy image
# !mv sad image
# !mv surprise image
# Out:
# Archive:  dataset_6_class.zip
#    creating: angry/
#   inflating: angry/angry19.jpeg
#   inflating: angry/angry20.jpeg
#   inflating: angry/angry21.jpeg
#   inflating: angry/angry22.jpg
#   inflating: angry/angry23.jpeg
#   inflating: angry/angry24.jpeg
#   inflating: angry/angry25.jpeg
#   inflating: angry/angry15.jpg
#   inflating: angry/angry1.jpeg
#   inflating: angry/angry2.jpeg
#   inflating: angry/angry3.jpeg
#   inflating: angry/angry4.jpg
#   inflating: angry/angry5.webp
#   inflating: angry/angry5.jpg
#   inflating: angry/angry6.jpg
#   inflating: angry/angry7.jpeg
#   inflating: angry/angry8.jpeg
#   inflating: angry/angry9.jpeg
#   inflating: angry/angry10.jpg
#   inflating: angry/angry11.webp
#   inflating: angry/angry12.jpg
#   inflating: angry/angry13.webp
#   inflating: angry/angry14.jpeg
#   inflating: angry/angry16.jpg
#   inflating: angry/angry17.webp
#   inflating: angry/angry18.jpeg
#    creating: happy/
#   inflating: happy/0.jpg
#   inflating: happy/1.jpg
#   inflating: happy/10.jpg
#   inflating: happy/11.jpg
#   inflating: happy/12.jpg
#   inflating: happy/13.jpg
#   inflating: happy/14.jpg
#   inflating: happy/15.jpg
#   inflating: happy/16.jpg
#   inflating: happy/17.jpg
#   inflating: happy/18.jpg
#   inflating: happy/19.jpg
#   inflating: happy/2.jpg
#   inflating: happy/3.jpg
#   inflating: happy/4.jpg
#   inflating: happy/5.jpg
#   inflating: happy/6.jpg
#   inflating: happy/7.jpg
#   inflating: happy/8.jpg
#   inflating: happy/9.jpg
#    creating: sad/
#   inflating: sad/sad0.jpg
#   inflating: sad/sad1.jpg
#   inflating: sad/sad10.jpg
#   inflating: sad/sad11.jpg
#   inflating: sad/sad12.jpg
#   inflating: sad/sad13.jpg
#   inflating: sad/sad14.jpg
#   inflating: sad/sad15.jpg
#   inflating: sad/sad3.jpg
#   inflating: sad/sad2.jpg
#   inflating: sad/sad3.webp
#   inflating: sad/sad4.jpg
#   inflating: sad/sad5.jpg
#   inflating: sad/sad6.jpg
#   inflating: sad/sad7.jpg
#   inflating: sad/sad8.jpg
#   inflating: sad/sad9.jpg
#    creating: surprise/
#   inflating: surprise/0.jpg
#   inflating: surprise/1.jpg
#   inflating: surprise/10.jpg
#   inflating: surprise/11.jpg
#   inflating: surprise/12.jpg
#   inflating: surprise/13.jpg
#   inflating: surprise/14.jpg
#   inflating: surprise/15.jpg
#   inflating: surprise/16.jpg
#   inflating: surprise/17.jpg
#   inflating: surprise/18.jpg
#   inflating: surprise/19.jpg
#   inflating: surprise/2.jpg
#   inflating: surprise/20.jpg
#   inflating: surprise/3.jpg
#   inflating: surprise/4.jpg
#   inflating: surprise/5.jpg
#   inflating: surprise/6.jpg
#   inflating: surprise/7.jpg
#   inflating: surprise/8.jpg
#   inflating: surprise/9.jpg

# %%
# load image
path_dir = os.path.join(os.getcwd(), 'image')
path_dir = sorted(glob.glob(path_dir + '/*'))

angry = glob.glob(path_dir[0] + '/*')
happy = glob.glob(path_dir[1] + '/*')
sad = glob.glob(path_dir[2] + '/*')
suprise = glob.glob(path_dir[3] + '/*')

# %%
img_cnt = len(angry) + len(happy) + len(sad) + len(suprise)
print(img_cnt)

class_names = ['angry', 'happy', 'sad', 'surprise']
num_classes = len(class_names)
print(class_names)
# Out:
# 84
# ['angry', 'happy', 'sad', 'surprise']

# %%
def load_image(path, img_size=(150, 150)):
    img = cv2.imread(path, 1)
    img = cv2.resize(img, img_size)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # OpenCV loads images with color channels
    # in BGR order. So we need to reverse them
    return img

# %%
def load_images(path_dir):
    images = []
    labels = []

    path_dir = sorted(glob.glob(path_dir + '/*'))
    print(path_dir)
    for paths in path_dir:
        paths = sorted(glob.glob(paths + '/*'))
        for path in paths:
            img = load_image(path)
            images.append(img)
            labels.append(class_names.index(os.path.basename(os.path.dirname(path))))
    return np.array(images), np.array(labels)

# %%
data_dir = os.path.join(os.getcwd(), 'image')
dataset = load_images(data_dir)
# Out:
# ['/content/gdrive/MyDrive/Colab Notebooks/AI/image/angry', '/content/gdrive/MyDrive/Colab Notebooks/AI/image/happy', '/content/gdrive/MyDrive/Colab Notebooks/AI/image/sad', '/content/gdrive/MyDrive/Colab Notebooks/AI/image/surprise']

# %%
for i in range(9):
  # print(class_names[dataset[1][i]])
  plt.subplot(3, 3, i+1)
  plt.title(class_names[dataset[1][i]])
  plt.imshow(dataset[0][i])

# %%
print(dataset[0].shape)
print(dataset[1].shape)
# Out:
# (84, 150, 150, 3)
# (84,)

# %%
# train test split
train_images, test_images, train_labels, test_labels = train_test_split(dataset[0], dataset[1], test_size=0.2, random_state=42)
print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (67, 150, 150, 3)
# (17, 150, 150, 3)
# (67,)
# (17,)

# %%
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255

train_labels = keras.utils.np_utils.to_categorical(train_labels, num_classes)
test_labels = keras.utils.np_utils.to_categorical(test_labels, num_classes)

print(train_images.shape)
print(test_images.shape)
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (67, 150, 150, 3)
# (17, 150, 150, 3)
# (67, 4)
# (17, 4)

# %%
def plot_history(history_fine):
  f1 = history_fine.history['acc']
  val_f1 = history_fine.history['val_acc']

  loss = history_fine.history['loss']
  val_loss = history_fine.history['val_loss']

  plt.figure(figsize=(8, 8))
  plt.subplot(2, 1, 1)
  plt.plot(f1, label='Acc')
  plt.plot(val_f1, label='Validation Acc')
  plt.legend(loc='lower right')
  plt.title('Accuracy')

  plt.subplot(2, 41, 2)
  plt.plot(loss, label='Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Loss')
  plt.xlabel('epoch')
  plt.show()

# %%
from keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(256, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(tf.keras.layers.BatchNormalization())

model.add(Conv2D(256, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(128,activation = 'relu',kernel_initializer = 'he_uniform'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(64, activation = 'relu',kernel_initializer = 'he_uniform'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))

model.add(Dense(4,activation = 'softmax'))

model.summary()

model.compile(loss='categorical_crossentropy', optimizer =tf.keras.optimizers.Adam(learning_rate=0.001), metrics=['acc'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=10,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

history = model.fit(train_images, train_labels, batch_size = 16, epochs = 50, validation_split = 0.2, callbacks=[early_stopping])
model.save('classification_4_emotion')
plot_history(history)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_160 (Conv2D)         (None, 150, 150, 256)     7168
#
#  max_pooling2d_41 (MaxPoolin  (None, 75, 75, 256)      0
#  g2D)
#
#  batch_normalization_150 (Ba  (None, 75, 75, 256)      1024
#  tchNormalization)
#
#  conv2d_161 (Conv2D)         (None, 75, 75, 256)       590080
#
#  batch_normalization_151 (Ba  (None, 75, 75, 256)      1024
#  tchNormalization)
#
#  max_pooling2d_42 (MaxPoolin  (None, 37, 37, 256)      0
#  g2D)
#
#  conv2d_162 (Conv2D)         (None, 37, 37, 64)        147520
#
#  batch_normalization_152 (Ba  (None, 37, 37, 64)       256
#  tchNormalization)
#
#  max_pooling2d_43 (MaxPoolin  (None, 18, 18, 64)       0
#  g2D)
#
#  flatten_17 (Flatten)        (None, 20736)             0
#
#  dense_49 (Dense)            (None, 128)               2654336
#
#  batch_normalization_153 (Ba  (None, 128)              512
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense
# 4/4 [==============================] - 0s 83ms/step - loss: 0.1760 - acc: 0.9245 - val_loss: 2.9283 - val_acc: 0.3571
# Epoch 30/50
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0748 - acc: 0.9811 - val_loss: 2.2079 - val_acc: 0.4286
# Epoch 31/50
# 4/4 [==============================] - 0s 83ms/step - loss: 0.1649 - acc: 0.9623 - val_loss: 1.8692 - val_acc: 0.5714
# Epoch 32/50
# 4/4 [==============================] - 0s 85ms/step - loss: 0.1956 - acc: 0.9623 - val_loss: 1.4996 - val_acc: 0.5000
# Epoch 33/50
# 4/4 [==============================] - 0s 80ms/step - loss: 0.1892 - acc: 0.9245 - val_loss: 1.6935 - val_acc: 0.3571
# Epoch 34/50
# 4/4 [==============================] - 0s 79ms/step - loss: 0.1519 - acc: 0.9623 - val_loss: 1.7775 - val_acc: 0.2857
# Epoch 35/50
# 4/4 [==============================] - 0s 82ms/step - loss: 0.1326 - acc: 0.9623 - val_loss: 1.7230 - val_acc: 0.3571
# Epoch 36/50
# 4/4 [==============================] - 0s 79ms/step - loss: 0.1228 - acc: 0.9811 - val_loss: 1.8573 - val_acc: 0.4286
# Epoch 37/50
# 4/4 [==============================] - 0s 78ms/step - loss: 0.1451 - acc: 0.9811 - val_loss: 2.0059 - val_acc: 0.4286
# Epoch 38/50
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0734 - acc: 1.0000 - val_loss: 1.8080 - val_acc: 0.5714
# Epoch 39/50
# 4/4 [==============================] - 0s 79ms/step - loss: 0.1273 - acc: 0.9623 - val_loss: 1.7321 - val_acc: 0.5000
# Epoch 40/50
# 4/4 [==============================] - 0s 79ms/step - loss: 0.2063 - acc: 0.9245 - val_loss: 1.8581 - val_acc: 0.5000
# Epoch 41/50
# 4/4 [==============================] - 0s 79ms/step - loss: 0.0539 - acc: 1.0000 - val_loss: 2.2526 - val_acc: 0.5000
# Epoch 42/50
# 3/4 [=====================>........] - ETA: 0s - loss: 0.0434 - acc: 1.0000Restoring model weights from the end of the best epoch: 32.
# 4/4 [==============================] - 0s 84ms/step - loss: 0.0410 - acc: 1.0000 - val_loss: 2.4791 - val_acc: 0.5000
# Epoch 42: early stopping
# INFO:tensorflow:Assets written to: classification_4_emotion/assets

# %%
print("test loss, test acc:", model.evaluate(test_images, test_labels))
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 1.1905 - acc: 0.5882
# test loss, test acc: [1.1904993057250977, 0.5882353186607361]

# %%
img_test = load_image('/content/gdrive/MyDrive/Colab Notebooks/AI/image/angry/angry12.jpg')

plt.imshow(img_test)

img_test = np.asarray(img_test)

img_test = img_test / 255
img_test = np.expand_dims(img_test, axis=0)

classe_num = np.argmax(model.predict(img_test))
plt.title("Predict: {}".format(class_names[classe_num]))
# Out:
# Text(0.5, 1.0, 'Predict: angry')

# %%
img_test = load_image('/content/gdrive/MyDrive/Colab Notebooks/AI/image/happy/10.jpg')
plt.imshow(img_test)

img_test = np.asarray(img_test)

img_test = img_test / 255
img_test = np.expand_dims(img_test, axis=0)

classe_num = np.argmax(model.predict(img_test))
plt.title("Predict: {}".format(class_names[classe_num]))
# Out:
# Text(0.5, 1.0, 'Predict: happy')

# %%
img_test = load_image('/content/gdrive/MyDrive/Colab Notebooks/AI/image/sad/sad10.jpg')
plt.imshow(img_test)

img_test = np.asarray(img_test)

img_test = img_test / 255
img_test = np.expand_dims(img_test, axis=0)

classe_num = np.argmax(model.predict(img_test))
plt.title("Predict: {}".format(class_names[classe_num]))
# Out:
# Text(0.5, 1.0, 'Predict: sad')

# %%
img_test = load_image('/content/gdrive/MyDrive/Colab Notebooks/AI/image/surprise/12.jpg')
plt.imshow(img_test)

img_test = np.asarray(img_test)

img_test = img_test / 255
img_test = np.expand_dims(img_test, axis=0)

classe_num = np.argmax(model.predict(img_test))
plt.title("Predict: {}".format(class_names[classe_num]))
# Out:
# Text(0.5, 1.0, 'Predict: surprise')
